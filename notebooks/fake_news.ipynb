# %%
print("Fake news detection process started")
# Out:
# Fake news detection process started

# %%
import pandas as pd

# %%
fake_data = pd.read_csv("../data/Fake.csv")

# %%
fake_data.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true_data = pd.read_csv("../data/True.csv")

# %%
true_data.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake_data["label"] = 0
true_data["label"] = 1

# %%
fake_data.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
true_data.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
data= pd.concat([fake_data, true_data])

# %%
data.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
data.shape
# Out:
# (44898, 5)

# %%
data = data.sample(frac=1)

# %%
data=data.reset_index(drop=True)

# %%
data.head()
# Out:
#    level_0  index                                              title  \
# 0    14876   1016  Top Republican senator testifies for Menendez ...
# 1    27496   4304  Trump says tax reform 'will be better' if Obam...
# 2    22959  15392  [VIDEO] HERO WHO EXPOSED PLANNED PARENTHOOD SA...
# 3    16898   5310  Deportation spat overshadows Trump envoys' tal...
# 4    15227  13689  Ireland set for election if Deputy PM does not...
#
#                                                 text       subject  \
# 0  (Reuters) - Republican U.S. Senator Lindsay Gr...  politicsNews
# 1  WASHINGTON (Reuters) - President Donald Trump ...  politicsNews
# 2  David Daleiden:  We probably have hundreds to ...      politics
# 3  MEXICO CITY (Reuters) - A bid by U.S. Presiden...  politicsNews
# 4  DUBLIN (Reuters) - Ireland s Deputy Prime Mini...     worldnews
#
#                  date  label
# 0   October 26, 2017       1
# 1     April 11, 2017       1
# 2        Jul 30, 2015      0
# 3  February 23, 2017       1
# 4  November 27, 2017       1

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer()

# %%
x= vectorizer.fit_transform(data["text"])

# %%
y= data["label"]

# %%
x.shape
# Out:
# (44898, 122002)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42
)

# %%
x_train.shape
# Out:
# (35918, 122002)

# %%
x_test.shape
# Out:
# (8980, 122002)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model= LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
predictions = model.predict(x_test)

# %%
predictions[:10]
# Out:
# array([0, 1, 0, 0, 0, 1, 0, 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(y_test, predictions)

# %%
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.9851893095768374

# %%
print("Accuracy Percentage:",accuracy*100)
# Out:
# Accuracy Percentage: 98.51893095768374

# %%
import re

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z\s]','',text)
    return text

# %%
news= "Government announces new education policy"

# %%
clean_news = clean_text(news)

# %%
news_vector = vectorizer.transform([clean_news])

# %%
prediction = model.predict(news_vector)

# %%
print(prediction)
# Out:
# [0]

# %%
if prediction[0] == 0:
    print("Fake News")
else:
    print("Real News")
# Out:
# Fake News

# %%
import pickle

# %%
with open("../model/fake_news_model.pkl","wb") as file:
    pickle.dump(model, file)

# %%
with open("../model/vectorizer.pkl","wb") as file:
    pickle.dump(vectorizer, file)
